# %%
import pandas as pd

# Excel dosyasının yolunu belirtin
file_path = 'Türkçe Nefret Söylemi Veriseti.xlsx'

# Excel dosyasını yükle
xlsx = pd.ExcelFile(file_path)

# Tüm sheet'leri listele
sheet_names = xlsx.sheet_names

# "TOPLAM" ve ilk sheet dışındaki sheet'leri seç
sheets_to_merge = [sheet for sheet in sheet_names if sheet != "TOPLAM" and sheet != sheet_names[0]]

# Seçilen sheet'leri birleştir
merged_data = pd.concat([xlsx.parse(sheet,header=1) for sheet in sheets_to_merge], ignore_index=True)

# Birleştirilen veriyi kaydetmek için bir CSV dosyası oluşturun (isteğe bağlı)
#merged_data.to_csv('merged_sheets.csv', index=False)

print(merged_data.head())  # Display the first few rows
print(merged_data.info())  # Understand data types and null values
print(merged_data.columns)

merged_data['Tweet'] = merged_data['Tweet'].str.lower()
merged_data['Tweet'] = merged_data['Tweet'].str.replace(r'[^\w\s]', '', regex=True)

import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords

stop_words = set(stopwords.words('turkish'))
merged_data['Tweet'] = merged_data['Tweet'].apply(
    lambda x: ' '.join(word for word in x.split() if word not in stop_words)
)


from snowballstemmer import TurkishStemmer

stemmer = TurkishStemmer()
merged_data['Tweet'] = merged_data['Tweet'].apply(
    lambda x: ' '.join(stemmer.stemWord(word) for word in x.split())
)

print("Boş Tweet sayısı:", merged_data['Tweet'].isnull().sum())
print("Boş Etiket sayısı:", merged_data['Etiket'].isnull().sum())
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#    row ID                                              Tweet     Etiket  \
# 0  Row589  ya orospu cocuklari hepiniz niye ayni anda yaz...     nefret
# 1  Row593  Ciddiye alan tüm dünyanın beynini sileyim.. \n...  saldırgan
# 2  Row600  Kayıtlı İstihdama geçiş programına göre (?)\nŞ...    hiçbiri
# 3  Row604  Hastaneye git Suriyeli. PTT ye git Suriyeli. P...     nefret
# 4  Row607               Cölesi bitmiş suriyeli gibiyim bugün    hiçbiri
#
#   Alt Etiket   Etiket.1 Alt Etiket.1   Etiket.2 Alt Etiket.2 Etiket.3  \
# 0      etnik     nefret        etnik     nefret        etnik      NaN
# 1        NaN  saldırgan          NaN  saldırgan          NaN      NaN
# 2        NaN    hiçbiri          NaN    hiçbiri          NaN      NaN
# 3      etnik     nefret        etnik     nefret        etnik      NaN
# 4        NaN     nefret        etnik    hiçbiri          NaN  hiçbiri
#
#   Alt Etiket.3  ...    User - Location User - Time Zone User - Statuses  \
# 0          NaN  ...            gökyüzü              NaN            9417
# 1          NaN  ...               İMKB              NaN            8747
# 2          NaN  ...              T. C.              NaN           27697
# 3          NaN  ...                NaN              NaN              15
# 4          NaN  ...  İstanbul, Türkiye              NaN             620
#
#    User - Followers  User - Friends  User - Favourites  Unnamed: 35  RowID  \
# 0              2860            2543            40313.0          NaN    NaN
# 1               314              15             5537.0          NaN    NaN
# 2             12548            8941            84426.0          NaN    NaN
# 3                 9              16               83.0          NaN    NaN
# 4               488             273              362.0          NaN    NaN
#
#    Unnamed: 22  Row ID
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
#
# [5 rows x 39 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10224 entries, 0 to 10223
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row ID                9959 non-null   object
#  1   Tweet                 10224 non-null  object
#  2   Etiket                10224 non-null  object
#  3   Alt Etiket            2336 non-null   object
#  4   Etiket.1              10224 non-null  object
#  5   Alt Etiket.1          2371 non-null   object
#  6   Etiket.2              10224 non-null  object
#  7   Alt Etiket.2          2312 non-null   object
#  8   Etiket.3              159 non-null    object
#  9   Alt Etiket.3          68 non-null     object
#  10  Tweet ID              10223 non-null  float64
#  11  Time                  10224 non-null  object
#  12  Favorited             10224 non-null  object
#  13  Retweeted             10224 non-null  int64
#  14  Is Favourited         10224 non-null  int64
#  15  Is Retweeted          10224 non-null  int64
#  16  Is Retweet            10224 non-null  int64
#  17  Retweet from          1 non-null      float64
#  18  Latitude              9 non-null      float64
#  19  Longitude             9 non-null      float64
#  20  Country               282 non-null    object
#  21  User                  10223 non-null  object
#  22  User - Profile image  122 non-null    object
#  23  User - Name           10222 non-null  object
#  24  User - ID             10195 non-null  object
#  25  User - Description    8393 non-null   object
#  26  User - URL            3046 non-null   object
#  27  User - Creation time  10103 non-null  object
#  28  User - Language       57 non-null     object
#  29  User - Location       5704 non-null   object
#  30  User - Time Zone      122 non-null    object
#  31  User - Statuses       10223 non-null  object
#  32  User - Followers      10224 non-null  object
#  33  User - Friends        10224 non-null  int64
#  34  User - Favourites     10103 non-null  float64
#  35  Unnamed: 35           1 non-null      float64
#  36  RowID                 210 non-null    object
#  37  Unnamed: 22           0 non-null      float64
#  38  Row ID                55 non-null     object
# dtypes: float64(7), int64(5), object(27)
# memory usage: 3.0+ MB
# None
# Index(['row ID', 'Tweet', 'Etiket', 'Alt Etiket', 'Etiket.1', 'Alt Etiket.1',
#        'Etiket.2', 'Alt Etiket.2', 'Etiket.3', 'Alt Etiket.3', 'Tweet ID',
#        'Time', 'Favorited', 'Retweeted', 'Is Favourited', 'Is Retweeted',
#        'Is Retweet', 'Retweet from', 'Latitude', 'Longitude', 'Country',
#        'User', 'User - Profile image', 'User - Name', 'User - ID',
#        'User - Description', 'User - URL', 'User - Creation time',
#        'User - Language', 'User - Location', 'User - Time Zone',
#        'User - Statuses', 'User - Followers', 'User - Friends',
#        'User - Favourites', 'Unnamed: 35', 'RowID', 'Unnamed: 22', 'Row ID'],
#       dtype='object')
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Boş Tweet sayısı: 0
# Boş Etiket sayısı: 0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
# Türkçe stop-word listesini indir
nltk.download('stopwords')
turkish_stop_words = stopwords.words('turkish')
# Metin ve etiketleri ayırma
texts = merged_data['Tweet']
labels = merged_data['Etiket']

# Label encoding
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

# Eğitim ve test bölme
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=42)

# TF-IDF Vectorizer tanımlama
max_features = 5000  #  maksimum özellik sayısını ayarlayın
vectorizer = TfidfVectorizer(max_features=max_features, stop_words=turkish_stop_words)

# Eğitim ve test verilerini vektörleştirme
X_train_tfidf = vectorizer.fit_transform(X_train).toarray()
X_test_tfidf = vectorizer.transform(X_test).toarray()

# Kontrol
print("Eğitim verisi şekli:", X_train_tfidf.shape)
print("Test verisi şekli:", X_test_tfidf.shape)
print("TF-IDF örnek değerler:", X_train_tfidf[0])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Eğitim verisi şekli: (8179, 5000)
# Test verisi şekli: (2045, 5000)
# TF-IDF örnek değerler: [0. 0. 0. ... 0. 0. 0.]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

def create_ann_model(hyperparameters, input_dim):
    """
    Hiperparametrelere göre ANN modelini oluşturur.
    """
    learning_rate = hyperparameters['learning_rate']
    num_layers = hyperparameters['num_layers']
    neurons_per_layer = hyperparameters['neurons_per_layer']
    activation = hyperparameters['activation']
    optimizer_name = hyperparameters['optimizer']

    # Optimizer seçimi
    if optimizer_name == 'Adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer_name == 'RMSprop':
        optimizer = RMSprop(learning_rate=learning_rate)
    elif optimizer_name == 'SGD':
        optimizer = SGD(learning_rate=learning_rate)

    # Model oluşturma
    model = Sequential()

    # Giriş katmanı
    model.add(Dense(neurons_per_layer, activation=activation, input_dim=input_dim))
    model.add(Dropout(0.2))

    # Ek katmanlar
    for _ in range(1, num_layers):
        model.add(Dense(neurons_per_layer, activation=activation))
        model.add(Dropout(0.2))

    # Çıkış katmanı
    model.add(Dense(1, activation='sigmoid')) 

    # Model derleme
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
import random

# Hiperparametre uzayı
hyperparameter_space = {
    'learning_rate': [0.0001, 0.1],
    'batch_size': [16, 32, 64, 128, 256],
    'num_layers': [1, 5],  # 'num_layers' eklendi
    'filters_per_layer': [8, 128],
    'kernel_size': [(3, 3), (5, 5)],
    'neurons_per_layer': [32, 128],  # 'neurons_per_layer' eklendi
    'activation': ['relu', 'tanh', 'sigmoid'],
    'pooling_type': ['MaxPooling', 'AveragePooling'],
    'optimizer': ['SGD', 'Adam', 'RMSprop']
}

# Popülasyon başlatma fonksiyonu
def initialize_population(pop_size, hyperparameter_space):
    population = []
    for _ in range(pop_size):
        individual = {
            'learning_rate': random.uniform(*hyperparameter_space['learning_rate']),
            'batch_size': random.choice(hyperparameter_space['batch_size']),
            'num_layers': random.randint(hyperparameter_space['num_layers'][0], hyperparameter_space['num_layers'][1]), # 'num_conv_layers' yerine 'num_layers' kullanıldı
            'filters_per_layer': random.choice(range(hyperparameter_space['filters_per_layer'][0],
                                                     hyperparameter_space['filters_per_layer'][1] + 1, 8)),
            'kernel_size': random.choice(hyperparameter_space['kernel_size']),
            'activation': random.choice(hyperparameter_space['activation']),
            'pooling_type': random.choice(hyperparameter_space['pooling_type']),
            'optimizer': random.choice(hyperparameter_space['optimizer']),
            'neurons_per_layer': random.choice(hyperparameter_space['neurons_per_layer']),
        }
        population.append(individual)
    return population

# %%
def evaluate_fitness(hyperparameters, X_train, y_train, X_test, y_test):
    # Modeli oluştur
    input_dim = X_train.shape[1]  # TF-IDF ile vektör boyutu
    model = create_ann_model(hyperparameters, input_dim=input_dim)

    # `batch_size` değerini ayarla
    batch_size = min(hyperparameters['batch_size'], len(X_train))

    # Modeli eğit
    history = model.fit(X_train, y_train, epochs=1, batch_size=batch_size, verbose=1)

    # Test doğruluğunu değerlendir
    _, accuracy = model.evaluate(X_test, y_test, verbose=0)
    return accuracy

# %%
def mutate(individual, hyperparameter_space):
    gene_to_mutate = random.choice(list(individual.keys()))
    if gene_to_mutate == 'learning_rate':
        individual[gene_to_mutate] = random.uniform(*hyperparameter_space['learning_rate'])
    elif gene_to_mutate == 'neurons_per_layer':
        individual[gene_to_mutate] = random.choice(hyperparameter_space['neurons_per_layer'])
    elif gene_to_mutate == 'batch_size':
        individual[gene_to_mutate] = random.choice(hyperparameter_space['batch_size'])
    elif gene_to_mutate == 'num_layers':
        individual[gene_to_mutate] = random.randint(hyperparameter_space['num_layers'][0], hyperparameter_space['num_layers'][1])
    elif gene_to_mutate == 'filters_per_layer':
        individual[gene_to_mutate] = random.choice(range(hyperparameter_space['filters_per_layer'][0],
                                                           hyperparameter_space['filters_per_layer'][1] + 1, 8))
    elif gene_to_mutate == 'activation':
        individual[gene_to_mutate] = random.choice(hyperparameter_space['activation'])
    elif gene_to_mutate == 'optimizer':
        individual[gene_to_mutate] = random.choice(hyperparameter_space['optimizer'])
    elif gene_to_mutate == 'pooling_type':
        individual[gene_to_mutate] = random.choice(hyperparameter_space['pooling_type'])
    elif gene_to_mutate == 'kernel_size':
        individual[gene_to_mutate] = random.choice(hyperparameter_space['kernel_size'])

# Crossover operatörü
def crossover(parent1, parent2):
    cut_point = random.randint(1, len(parent1) - 1)
    child1 = {**dict(list(parent1.items())[:cut_point]), **dict(list(parent2.items())[cut_point:])}
    child2 = {**dict(list(parent2.items())[:cut_point]), **dict(list(parent1.items())[cut_point:])}
    return child1, child2

# %%
def tournament_selection(population, fitness_scores, tournament_size=5):
    """
    Turnuva seçimi uygular: Rastgele seçilen bireyler arasında en iyisini seçer.
    """
    selected = []
    for _ in range(len(population)):
        # Turnuvaya katılacak bireyleri rastgele seç
        tournament = random.sample(list(zip(population, fitness_scores)), tournament_size)
        # Turnuvanın en iyi bireyini seç
        winner = max(tournament, key=lambda x: x[1])
        selected.append(winner[0])
    return selected

# %%
def survivor_selection(population, fitness_scores, pop_size):
    """
    Fitness-based Survivor Selection uygular: Eski ve yeni popülasyonu birleştirir,
    en iyi bireyleri fitness skorlarına göre seçer.
    """
    # Popülasyonu ve fitness skorlarını birleştir
    combined_population = population
    combined_fitness_scores = fitness_scores

    # Fitness skorlarına göre sıralama yap
    sorted_population = [ind for _, ind in sorted(zip(combined_fitness_scores, combined_population),
                                                  key=lambda pair: pair[0], reverse=True)]

    # En iyi popülasyonu seç
    return sorted_population[:pop_size]

# %%
def genetic_algorithm(X_train, y_train, X_test, y_test, hyperparameter_space,
                      pop_size=10, generations=10, mutation_prob=0.05, crossover_prob=0.3, tournament_size=5):
    """
    Genetik algoritmayı uygular ve en iyi kromozomu döndürür.
    """
    population = initialize_population(pop_size, hyperparameter_space)
    best_chromosomes = []  # En iyi kromozomları her nesil için sakla
    generation_accuracies = []  # Her nesildeki doğruluk değerlerini sakla

    # Global en iyi doğruluğu ve kromozomu takip et
    best_accuracy = 0
    best_chromosome = None

    for generation in range(generations):
        # Fitness değerlendirmesi
        fitness_scores = [evaluate_fitness(ind, X_train, y_train, X_test, y_test)
                          for ind in population]

        # Her nesildeki en iyi doğruluk değerini kaydet
        generation_best_accuracy = max(fitness_scores)
        generation_accuracies.append(generation_best_accuracy)

        # En iyi kromozomu kontrol et ve global olarak güncelle
        if generation_best_accuracy > best_accuracy:
            best_accuracy = generation_best_accuracy
            best_chromosome = population[fitness_scores.index(generation_best_accuracy)]

        # Parent Selection: Turnuva seçimi
        selected_population = tournament_selection(population, fitness_scores, tournament_size)

        # Yeni popülasyonu oluşturma
        next_population = []

        while len(next_population) < pop_size:
            if random.random() < crossover_prob:
                # Crossover uygulama
                parent1, parent2 = random.sample(selected_population, 2)
                child1, child2 = crossover(parent1, parent2)
                if random.random() < mutation_prob:
                    mutate(child1, hyperparameter_space)
                    mutate(child2, hyperparameter_space)
                next_population += [child1, child2]
            else:
                # Mutasyon uygulama
                child = random.choice(selected_population).copy()
                mutate(child, hyperparameter_space)
                next_population.append(child)

        # Survivor Selection: Fitness-based Survivor Selection
        population = survivor_selection(next_population, [evaluate_fitness(ind, X_train, y_train, X_test, y_test)
                                                           for ind in next_population], pop_size)

        # Her nesilin en iyi doğruluk değerini yazdır
        print(f"Generation {generation + 1}, Best Accuracy (Current): {generation_best_accuracy:.4f}")
        print(f"Overall Best Accuracy: {best_accuracy:.4f}")

    # En iyi kromozomu döndürme
    print("\nFinal Best Chromosome and Accuracy:")
    print(f"Best Chromosome: {best_chromosome}")
    print(f"Best Accuracy: {best_accuracy:.4f}")

    # Tüm nesillerin doğruluk değerlerini döndür
    return best_chromosome, best_accuracy, generation_accuracies

# %%
# 10 popülasyon, 10 iterasyon
print("\nRunning GA with 10 population and 10 generations...\n")
# Assign the third returned value to a variable named 'generation_accuracies_10_10'
best_chromosome_10_10, best_accuracy_10_10, generation_accuracies_10_10 = genetic_algorithm(
    X_train_tfidf, y_train, X_test_tfidf, y_test,

    hyperparameter_space=hyperparameter_space,
    pop_size=10, generations=10, mutation_prob=0.05, crossover_prob=0.3
)

# Sonuçları yazdır
print("\nResults for 10 Population and 10 Generations:")
print(f"Best Chromosome: {best_chromosome_10_10}")
print(f"Best Accuracy: {best_accuracy_10_10:.4f}")

# 10 popülasyon, 50 iterasyon
print("\nRunning GA with 10 population and 50 generations...\n")
best_chromosome_10_50, best_accuracy_10_50,generation_accuracies_10_50 = genetic_algorithm(
    X_train_tfidf, y_train, X_test_tfidf, y_test,

    hyperparameter_space=hyperparameter_space,
    pop_size=10, generations=50, mutation_prob=0.05, crossover_prob=0.3
)

# Sonuçları yazdır
print("\nResults for 10 Population and 50 Generations:")
print(f"Best Chromosome: {best_chromosome_10_50}")
print(f"Best Accuracy: {best_accuracy_10_50:.4f}")

# Karşılaştırma
print("\nComparison:")
print(f"Accuracy Improvement: {best_accuracy_10_50 - best_accuracy_10_10:.4f}")
# Out:
# Running GA with 10 population and 10 generations...
#
# 512/512 [==============================] - 3s 4ms/step - loss: 0.5915 - accuracy: 0.7472
# 256/256 [==============================] - 4s 11ms/step - loss: 0.5851 - accuracy: 0.7555
# 256/256 [==============================] - 4s 11ms/step - loss: 0.5088 - accuracy: 0.7816
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4349 - accuracy: 0.8144
# 256/256 [==============================] - 2s 3ms/step - loss: 0.5891 - accuracy: 0.7566
# 32/32 [==============================] - 1s 13ms/step - loss: 1.2575 - accuracy: 0.6441
# 256/256 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7676
# 512/512 [==============================] - 6s 10ms/step - loss: 0.4508 - accuracy: 0.8111
# 32/32 [==============================] - 1s 14ms/step - loss: 0.6074 - accuracy: 0.7480
# 32/32 [==============================] - 1s 11ms/step - loss: 0.8829 - accuracy: 0.6835
# 512/512 [==============================] - 3s 5ms/step - loss: 0.6010 - accuracy: 0.7573
# 512/512 [==============================] - 5s 9ms/step - loss: 0.4336 - accuracy: 0.8182
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4556 - accuracy: 0.8003
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4183 - accuracy: 0.8172
# 512/512 [==============================] - 5s 7ms/step - loss: 0.4464 - accuracy: 0.8171
# 512/512 [==============================] - 5s 9ms/step - loss: 0.4456 - accuracy: 0.8178
# 512/512 [==============================] - 2s 2ms/step - loss: 0.4651 - accuracy: 0.8007
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4591 - accuracy: 0.7961
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4453 - accuracy: 0.8106
# 512/512 [==============================] - 5s 9ms/step - loss: 0.4450 - accuracy: 0.8113
# Generation 1, Best Accuracy (Current): 0.8411
# Overall Best Accuracy: 0.8411
# 512/512 [==============================] - 6s 10ms/step - loss: 0.4351 - accuracy: 0.8111
# 512/512 [==============================] - 6s 10ms/step - loss: 0.4459 - accuracy: 0.8142
# 512/512 [==============================] - 6s 10ms/step - loss: 0.4487 - accuracy: 0.8165
# 512/512 [==============================] - 4s 7ms/step - loss: 0.4473 - accuracy: 0.8133
# 128/128 [==============================] - 3s 13ms/step - loss: 0.4488 - accuracy: 0.8100
# 512/512 [==============================] - 2s 2ms/step - loss: 0.4552 - accuracy: 0.8076
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4538 - accuracy: 0.8077
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4290 - accuracy: 0.8149
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4374 - accuracy: 0.8049
# 512/512 [==============================] - 3s 5ms/step - loss: 0.5998 - accuracy: 0.7558
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4693 - accuracy: 0.8006
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4435 - accuracy: 0.8029
# 512/512 [==============================] - 5s 9ms/step - loss: 0.4450 - accuracy: 0.8135
# 512/512 [==============================] - 3s 3ms/step - loss: 0.4649 - accuracy: 0.8039
# 512/512 [==============================] - 7s 12ms/step - loss: 0.4386 - accuracy: 0.8123
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4352 - accuracy: 0.8069
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4619 - accuracy: 0.7975
# 512/512 [==============================] - 5s 8ms/step - loss: 0.4818 - accuracy: 0.8046
# 512/512 [==============================] - 7s 11ms/step - loss: 0.4318 - accuracy: 0.8153
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4379 - accuracy: 0.8095
# Generation 2, Best Accuracy (Current): 0.8416
# Overall Best Accuracy: 0.8416
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4466 - accuracy: 0.8035
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4551 - accuracy: 0.8062
# 512/512 [==============================] - 6s 10ms/step - loss: 0.4653 - accuracy: 0.8151
# 128/128 [==============================] - 2s 14ms/step - loss: 0.4602 - accuracy: 0.7994
# 512/512 [==============================] - 5s 7ms/step - loss: 0.4513 - accuracy: 0.8142
# 512/512 [==============================] - 6s 11ms/step - loss: 0.4310 - accuracy: 0.8173
# 512/512 [==============================] - 6s 11ms/step - loss: 0.4454 - accuracy: 0.8109
# 512/512 [==============================] - 2s 3ms/step - loss: 0.4511 - accuracy: 0.8096
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4618 - accuracy: 0.7990
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4415 - accuracy: 0.8036
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4422 - accuracy: 0.8061
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4489 - accuracy: 0.8099
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4843 - accuracy: 0.7948
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4524 - accuracy: 0.8077
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4404 - accuracy: 0.8069
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4500 - accuracy: 0.7979
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4367 - accuracy: 0.8099
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4560 - accuracy: 0.8032
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4362 - accuracy: 0.8131
# 128/128 [==============================] - 3s 13ms/step - loss: 0.4490 - accuracy: 0.8038
# Generation 3, Best Accuracy (Current): 0.8504
# Overall Best Accuracy: 0.8504
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4405 - accuracy: 0.8094
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4396 - accuracy: 0.8153
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4586 - accuracy: 0.8023
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4973 - accuracy: 0.7864
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4487 - accuracy: 0.8002
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4522 - accuracy: 0.8002
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4426 - accuracy: 0.8093
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4282 - accuracy: 0.8154
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4384 - accuracy: 0.8068
# 128/128 [==============================] - 3s 13ms/step - loss: 0.4372 - accuracy: 0.8111
# 128/128 [==============================] - 2s 11ms/step - loss: 0.5337 - accuracy: 0.7918
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4643 - accuracy: 0.8056
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4433 - accuracy: 0.8039
# 512/512 [==============================] - 6s 8ms/step - loss: 0.4669 - accuracy: 0.8098
# 128/128 [==============================] - 3s 14ms/step - loss: 0.4473 - accuracy: 0.8077
# 128/128 [==============================] - 3s 14ms/step - loss: 0.4595 - accuracy: 0.8016
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4513 - accuracy: 0.8051
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4412 - accuracy: 0.8116
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4471 - accuracy: 0.8011
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4435 - accuracy: 0.8098
# Generation 4, Best Accuracy (Current): 0.8460
# Overall Best Accuracy: 0.8504
# 128/128 [==============================] - 2s 11ms/step - loss: 0.5039 - accuracy: 0.7810
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4539 - accuracy: 0.8085
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4335 - accuracy: 0.8115
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4663 - accuracy: 0.7958
# 128/128 [==============================] - 3s 12ms/step - loss: 0.4123 - accuracy: 0.8168
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4570 - accuracy: 0.7974
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4539 - accuracy: 0.8104
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4489 - accuracy: 0.8079
# 128/128 [==============================] - 3s 13ms/step - loss: 0.5620 - accuracy: 0.7736
# 512/512 [==============================] - 5s 9ms/step - loss: 0.4704 - accuracy: 0.8067
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4578 - accuracy: 0.8056
# 128/128 [==============================] - 3s 13ms/step - loss: 0.4389 - accuracy: 0.8087
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4332 - accuracy: 0.8121
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4512 - accuracy: 0.7961
# 128/128 [==============================] - 2s 11ms/step - loss: 0.5235 - accuracy: 0.7763
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4448 - accuracy: 0.8055
# 128/128 [==============================] - 2s 10ms/step - loss: 0.6978 - accuracy: 0.7107
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4518 - accuracy: 0.8050
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4495 - accuracy: 0.8040
# 128/128 [==============================] - 3s 13ms/step - loss: 0.6463 - accuracy: 0.7634
# Generation 5, Best Accuracy (Current): 0.8484
# Overall Best Accuracy: 0.8504
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4284 - accuracy: 0.8088
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4656 - accuracy: 0.7952
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4215 - accuracy: 0.8095
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4580 - accuracy: 0.8030
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4408 - accuracy: 0.8087
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4427 - accuracy: 0.8069
# 128/128 [==============================] - 2s 12ms/step - loss: 0.5174 - accuracy: 0.7849
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4699 - accuracy: 0.7975
# 128/128 [==============================] - 2s 10ms/step - loss: 0.6678 - accuracy: 0.7540
# 128/128 [==============================] - 2s 10ms/step - loss: 0.6726 - accuracy: 0.7145
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4974 - accuracy: 0.7931
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4834 - accuracy: 0.7968
# 128/128 [==============================] - 2s 11ms/step - loss: 0.5323 - accuracy: 0.7863
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4245 - accuracy: 0.8118
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4301 - accuracy: 0.8138
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4302 - accuracy: 0.8138
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4552 - accuracy: 0.8051
# 128/128 [==============================] - 3s 11ms/step - loss: 0.4227 - accuracy: 0.8129
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4374 - accuracy: 0.8176
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4363 - accuracy: 0.8126
# Generation 6, Best Accuracy (Current): 0.8469
# Overall Best Accuracy: 0.8504
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4312 - accuracy: 0.8111
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4493 - accuracy: 0.8068
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4289 - accuracy: 0.8151
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4291 - accuracy: 0.8109
# 128/128 [==============================] - 2s 12ms/step - loss: 0.5240 - accuracy: 0.7822
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4273 - accuracy: 0.8148
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4209 - accuracy: 0.8117
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4550 - accuracy: 0.8065
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4265 - accuracy: 0.8164
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4920 - accuracy: 0.7990
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4662 - accuracy: 0.7942
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4292 - accuracy: 0.8157
# 64/64 [==============================] - 2s 16ms/step - loss: 0.4553 - accuracy: 0.8012
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4305 - accuracy: 0.8115
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4372 - accuracy: 0.8109
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4346 - accuracy: 0.8080
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4479 - accuracy: 0.8038
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4160 - accuracy: 0.8177
# 128/128 [==============================] - 2s 9ms/step - loss: 0.6138 - accuracy: 0.7549
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4776 - accuracy: 0.7992
# Generation 7, Best Accuracy (Current): 0.8494
# Overall Best Accuracy: 0.8504
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4321 - accuracy: 0.8113
# 64/64 [==============================] - 1s 13ms/step - loss: 0.4484 - accuracy: 0.7983
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4518 - accuracy: 0.8088
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4286 - accuracy: 0.8176
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4988 - accuracy: 0.7992
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4322 - accuracy: 0.8109
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4115 - accuracy: 0.8204
# 128/128 [==============================] - 3s 14ms/step - loss: 0.4213 - accuracy: 0.8204
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4455 - accuracy: 0.8110
# 128/128 [==============================] - 2s 9ms/step - loss: 0.6126 - accuracy: 0.7558
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4286 - accuracy: 0.8066
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4250 - accuracy: 0.8139
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4218 - accuracy: 0.8137
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4829 - accuracy: 0.8040
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4346 - accuracy: 0.8100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4445 - accuracy: 0.8107
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4219 - accuracy: 0.8139
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4227 - accuracy: 0.8106
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4304 - accuracy: 0.8101
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4343 - accuracy: 0.8098
# Generation 8, Best Accuracy (Current): 0.8465
# Overall Best Accuracy: 0.8504
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4337 - accuracy: 0.8098
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4232 - accuracy: 0.8178
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4316 - accuracy: 0.8137
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4278 - accuracy: 0.8175
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4254 - accuracy: 0.8171
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4276 - accuracy: 0.8146
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4241 - accuracy: 0.8181
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4376 - accuracy: 0.8068
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4895 - accuracy: 0.7909
# 128/128 [==============================] - 1s 5ms/step - loss: 0.4298 - accuracy: 0.8154
# 128/128 [==============================] - 3s 13ms/step - loss: 0.4227 - accuracy: 0.8170
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4289 - accuracy: 0.8107
# 128/128 [==============================] - 2s 12ms/step - loss: 0.5354 - accuracy: 0.7799
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4791 - accuracy: 0.7997
# 128/128 [==============================] - 2s 9ms/step - loss: 0.5481 - accuracy: 0.7820
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4734 - accuracy: 0.7967
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4834 - accuracy: 0.7930
# 128/128 [==============================] - 2s 9ms/step - loss: 0.6165 - accuracy: 0.7527
# 128/128 [==============================] - 2s 13ms/step - loss: 0.5546 - accuracy: 0.8111
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4358 - accuracy: 0.8090
# Generation 9, Best Accuracy (Current): 0.8474
# Overall Best Accuracy: 0.8504
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4363 - accuracy: 0.8090
# 128/128 [==============================] - 2s 11ms/step - loss: 0.5055 - accuracy: 0.7901
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4750 - accuracy: 0.7999
# 128/128 [==============================] - 2s 10ms/step - loss: 0.4267 - accuracy: 0.8099
# 128/128 [==============================] - 2s 10ms/step - loss: 0.5075 - accuracy: 0.7902
# 128/128 [==============================] - 2s 12ms/step - loss: 0.5124 - accuracy: 0.7798
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4822 - accuracy: 0.7974
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4354 - accuracy: 0.8098
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4970 - accuracy: 0.7968
# 128/128 [==============================] - 1s 6ms/step - loss: 0.6168 - accuracy: 0.7511
# 128/128 [==============================] - 2s 8ms/step - loss: 0.5144 - accuracy: 0.7866
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4354 - accuracy: 0.8083
# 128/128 [==============================] - 3s 14ms/step - loss: 0.5073 - accuracy: 0.8018
# 128/128 [==============================] - 2s 13ms/step - loss: 0.4732 - accuracy: 0.8035
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4710 - accuracy: 0.7934
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4909 - accuracy: 0.7840
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4828 - accuracy: 0.7919
# 128/128 [==============================] - 2s 12ms/step - loss: 0.4726 - accuracy: 0.7990
# 128/128 [==============================] - 2s 11ms/step - loss: 0.4828 - accuracy: 0.7972
# 128/128 [==============================] - 2s 9ms/step - loss: 0.4179 - accuracy: 0.8175
# Generation 10, Best Accuracy (Current): 0.8455
# Overall Best Accuracy: 0.8504
#
# Final Best Chromosome and Accuracy:
# Best Chromosome: {'learning_rate': 0.02933297374961518, 'batch_size': 64, 'num_layers': 2, 'filters_per_layer': 72, 'kernel_size': (3, 3), 'activation': 'relu', 'pooling_type': 'AveragePooling', 'optimizer': 'RMSprop', 'neurons_per_layer': 128}
# Best Accuracy: 0.8504
#
# Results for 10 Population and 10 Generations:
# Best Chromosome: {'learning_rate': 0.02933297374961518, 'batch_size': 64, 'num_layers': 2, 'filters_per_layer': 72, 'kernel_size': (3, 3), 'activation': 'relu', 'pooling_type': 'AveragePooling', 'optimizer': 'RMSprop', 'neurons_per_layer': 128}
# Best Accuracy: 0.8504
#
# Running GA with 10 population and 50 generations...
#
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5749 - accuracy: 0.7540
# 512/512 [==============================] - 7s 12ms/step - loss: 0.6897 - accuracy: 0.7507
# 32/32 [==============================] - 1s 6ms/step - loss: 0.5888 - accuracy: 0.7487
# 256/256 [==============================] - 1s 3ms/step - loss: 0.5905 - accuracy: 0.7483
# 32/32 [==============================] - 1s 20ms/step - loss: 0.6222 - accuracy: 0.7555
# 512/512 [==============================] - 4s 6ms/step - loss: 0.5812 - accuracy: 0.7564
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4619 - accuracy: 0.7909
# 128/128 [==============================] - 2s 13ms/step - loss: 0.5707 - accuracy: 0.7618
# 128/128 [==============================] - 1s 4ms/step - loss: 0.5848 - accuracy: 0.7545
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4583 - accuracy: 0.7967
# 32/32 [==============================] - 1s 6ms/step - loss: 0.6669 - accuracy: 0.7276
# 32/32 [==============================] - 1s 8ms/step - loss: 0.5321 - accuracy: 0.7513
# 32/32 [==============================] - 1s 16ms/step - loss: 0.6156 - accuracy: 0.7447
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4560 - accuracy: 0.7945
# 32/32 [==============================] - 1s 6ms/step - loss: 0.6095 - accuracy: 0.7571
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4309 - accuracy: 0.8034
# 128/128 [==============================] - 2s 14ms/step - loss: 0.5141 - accuracy: 0.7802
# 32/32 [==============================] - 2s 22ms/step - loss: 0.6175 - accuracy: 0.7555
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4697 - accuracy: 0.7843
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4960 - accuracy: 0.7673
# Generation 1, Best Accuracy (Current): 0.8474
# Overall Best Accuracy: 0.8474
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4505 - accuracy: 0.7957
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4559 - accuracy: 0.7977
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4293 - accuracy: 0.8063
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5192 - accuracy: 0.7805
# 128/128 [==============================] - 2s 12ms/step - loss: 0.5478 - accuracy: 0.7684
# 32/32 [==============================] - 1s 8ms/step - loss: 0.5116 - accuracy: 0.7525
# 32/32 [==============================] - 1s 7ms/step - loss: 0.6674 - accuracy: 0.7212
# 32/32 [==============================] - 1s 16ms/step - loss: 0.6084 - accuracy: 0.7447
# 32/32 [==============================] - 1s 6ms/step - loss: 0.6270 - accuracy: 0.7453
# 32/32 [==============================] - 1s 13ms/step - loss: 0.6274 - accuracy: 0.7496
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4659 - accuracy: 0.7895
# 32/32 [==============================] - 1s 8ms/step - loss: 0.5028 - accuracy: 0.7747
# 32/32 [==============================] - 1s 20ms/step - loss: 0.4341 - accuracy: 0.8063
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4599 - accuracy: 0.7934
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4615 - accuracy: 0.7953
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4603 - accuracy: 0.7961
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4520 - accuracy: 0.7934
# 32/32 [==============================] - 1s 7ms/step - loss: 0.6797 - accuracy: 0.6964
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4496 - accuracy: 0.7988
# 256/256 [==============================] - 1s 3ms/step - loss: 0.4193 - accuracy: 0.8144
# Generation 2, Best Accuracy (Current): 0.8469
# Overall Best Accuracy: 0.8474
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4724 - accuracy: 0.7909
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4480 - accuracy: 0.7957
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4611 - accuracy: 0.7919
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4377 - accuracy: 0.7990
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4484 - accuracy: 0.8008
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4546 - accuracy: 0.7990
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4610 - accuracy: 0.7912
# 32/32 [==============================] - 1s 8ms/step - loss: 0.5053 - accuracy: 0.7728
# 256/256 [==============================] - 1s 3ms/step - loss: 0.4153 - accuracy: 0.8159
# 32/32 [==============================] - 1s 7ms/step - loss: 0.6770 - accuracy: 0.7063
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4546 - accuracy: 0.7825
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4296 - accuracy: 0.8030
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4589 - accuracy: 0.7966
# 32/32 [==============================] - 1s 17ms/step - loss: 0.4800 - accuracy: 0.7808
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4559 - accuracy: 0.7986
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5869 - accuracy: 0.7558
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4134 - accuracy: 0.8198
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4544 - accuracy: 0.7950
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4528 - accuracy: 0.7963
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4579 - accuracy: 0.7984
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4486 - accuracy: 0.7996
# Generation 3, Best Accuracy (Current): 0.8523
# Overall Best Accuracy: 0.8523
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4329 - accuracy: 0.8013
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4459 - accuracy: 0.8006
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4480 - accuracy: 0.8016
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4580 - accuracy: 0.7946
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4543 - accuracy: 0.7966
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4606 - accuracy: 0.7955
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4703 - accuracy: 0.7805
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4833 - accuracy: 0.7792
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4561 - accuracy: 0.7939
# 128/128 [==============================] - 1s 4ms/step - loss: 0.4107 - accuracy: 0.8181
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5021 - accuracy: 0.7734
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4562 - accuracy: 0.7918
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4685 - accuracy: 0.7928
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4480 - accuracy: 0.7977
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4416 - accuracy: 0.8008
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4637 - accuracy: 0.7914
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4524 - accuracy: 0.8013
# 32/32 [==============================] - 2s 8ms/step - loss: 0.4640 - accuracy: 0.7923
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4601 - accuracy: 0.7929
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4601 - accuracy: 0.7924
# Generation 4, Best Accuracy (Current): 0.8504
# Overall Best Accuracy: 0.8523
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4686 - accuracy: 0.7917
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4639 - accuracy: 0.7933
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4474 - accuracy: 0.7970
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4541 - accuracy: 0.7955
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4519 - accuracy: 0.7959
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4534 - accuracy: 0.7955
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4559 - accuracy: 0.7973
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4733 - accuracy: 0.7909
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5096 - accuracy: 0.7609
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4279 - accuracy: 0.8039
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4542 - accuracy: 0.7970
# 64/64 [==============================] - 1s 5ms/step - loss: 0.4246 - accuracy: 0.8135
# 32/32 [==============================] - 1s 6ms/step - loss: 0.5055 - accuracy: 0.7760
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4190 - accuracy: 0.8109
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4537 - accuracy: 0.8028
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4593 - accuracy: 0.7953
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4682 - accuracy: 0.7896
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4634 - accuracy: 0.7888
# 32/32 [==============================] - 1s 7ms/step - loss: 0.6717 - accuracy: 0.7160
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4445 - accuracy: 0.8030
# Generation 5, Best Accuracy (Current): 0.8499
# Overall Best Accuracy: 0.8523
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4511 - accuracy: 0.7963
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4671 - accuracy: 0.7925
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4656 - accuracy: 0.7895
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4539 - accuracy: 0.7958
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4585 - accuracy: 0.7952
# 64/64 [==============================] - 1s 5ms/step - loss: 0.4227 - accuracy: 0.8068
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4253 - accuracy: 0.8126
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4479 - accuracy: 0.7983
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4939 - accuracy: 0.7807
# 32/32 [==============================] - 1s 7ms/step - loss: 0.6759 - accuracy: 0.7102
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4251 - accuracy: 0.8079
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4447 - accuracy: 0.7990
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4313 - accuracy: 0.8057
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4213 - accuracy: 0.8045
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4503 - accuracy: 0.7959
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4236 - accuracy: 0.8112
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4539 - accuracy: 0.7984
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4244 - accuracy: 0.8084
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4255 - accuracy: 0.8074
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4454 - accuracy: 0.7980
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4122 - accuracy: 0.8135
# Generation 6, Best Accuracy (Current): 0.8504
# Overall Best Accuracy: 0.8523
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4744 - accuracy: 0.7875
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4258 - accuracy: 0.8109
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4198 - accuracy: 0.8109
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4343 - accuracy: 0.8025
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4673 - accuracy: 0.7920
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4186 - accuracy: 0.8090
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4456 - accuracy: 0.7968
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4289 - accuracy: 0.8005
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4298 - accuracy: 0.8079
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4297 - accuracy: 0.8022
# 32/32 [==============================] - 1s 7ms/step - loss: 0.6104 - accuracy: 0.7155
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4241 - accuracy: 0.8089
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4291 - accuracy: 0.8127
# 32/32 [==============================] - 1s 16ms/step - loss: 0.4362 - accuracy: 0.8014
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4292 - accuracy: 0.8091
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4495 - accuracy: 0.7970
# 32/32 [==============================] - 1s 15ms/step - loss: 0.5129 - accuracy: 0.7733
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4636 - accuracy: 0.7936
# 32/32 [==============================] - 2s 18ms/step - loss: 0.4280 - accuracy: 0.8069
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4418 - accuracy: 0.8011
# Generation 7, Best Accuracy (Current): 0.8528
# Overall Best Accuracy: 0.8528
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4275 - accuracy: 0.8060
# 32/32 [==============================] - 1s 19ms/step - loss: 0.4316 - accuracy: 0.8002
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4209 - accuracy: 0.8073
# 32/32 [==============================] - 1s 17ms/step - loss: 0.4271 - accuracy: 0.8034
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4329 - accuracy: 0.8063
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4675 - accuracy: 0.7977
# 32/32 [==============================] - 1s 16ms/step - loss: 0.4288 - accuracy: 0.8050
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4718 - accuracy: 0.7874
# 32/32 [==============================] - 1s 16ms/step - loss: 0.4862 - accuracy: 0.7781
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5859 - accuracy: 0.7569
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4301 - accuracy: 0.8063
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4242 - accuracy: 0.8116
# 256/256 [==============================] - 2s 3ms/step - loss: 0.4153 - accuracy: 0.8194
# 512/512 [==============================] - 5s 7ms/step - loss: 0.4170 - accuracy: 0.8173
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4214 - accuracy: 0.8106
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4336 - accuracy: 0.8051
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5609 - accuracy: 0.7585
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4220 - accuracy: 0.8098
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4298 - accuracy: 0.8041
# 32/32 [==============================] - 1s 7ms/step - loss: 0.6371 - accuracy: 0.7464
# Generation 8, Best Accuracy (Current): 0.8533
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4288 - accuracy: 0.8062
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4265 - accuracy: 0.8047
# 32/32 [==============================] - 1s 17ms/step - loss: 0.4338 - accuracy: 0.8001
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4213 - accuracy: 0.8132
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4165 - accuracy: 0.8054
# 256/256 [==============================] - 1s 3ms/step - loss: 0.4107 - accuracy: 0.8222
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4201 - accuracy: 0.8076
# 512/512 [==============================] - 4s 7ms/step - loss: 0.4163 - accuracy: 0.8225
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5773 - accuracy: 0.7660
# 32/32 [==============================] - 1s 6ms/step - loss: 0.6361 - accuracy: 0.7447
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4305 - accuracy: 0.8051
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5762 - accuracy: 0.7558
# 256/256 [==============================] - 1s 3ms/step - loss: 0.4028 - accuracy: 0.8244
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4182 - accuracy: 0.8100
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4248 - accuracy: 0.8082
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4294 - accuracy: 0.8080
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4315 - accuracy: 0.7988
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4301 - accuracy: 0.8072
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4290 - accuracy: 0.8040
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4286 - accuracy: 0.8089
# Generation 9, Best Accuracy (Current): 0.8509
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4322 - accuracy: 0.8068
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4230 - accuracy: 0.8032
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4275 - accuracy: 0.8058
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4206 - accuracy: 0.8065
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4275 - accuracy: 0.8066
# 256/256 [==============================] - 1s 3ms/step - loss: 0.3999 - accuracy: 0.8220
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4321 - accuracy: 0.8033
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4246 - accuracy: 0.8098
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4261 - accuracy: 0.8054
# 32/32 [==============================] - 1s 7ms/step - loss: 0.5755 - accuracy: 0.7547
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4336 - accuracy: 0.8006
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4212 - accuracy: 0.8076
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4252 - accuracy: 0.8113
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4323 - accuracy: 0.8071
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4262 - accuracy: 0.8060
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4563 - accuracy: 0.7893
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4269 - accuracy: 0.8091
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4348 - accuracy: 0.8013
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4222 - accuracy: 0.8110
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4668 - accuracy: 0.7756
# Generation 10, Best Accuracy (Current): 0.8509
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4316 - accuracy: 0.8061
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4625 - accuracy: 0.7832
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4303 - accuracy: 0.8039
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4232 - accuracy: 0.8061
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4281 - accuracy: 0.8082
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4234 - accuracy: 0.8072
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4111 - accuracy: 0.8154
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4372 - accuracy: 0.8049
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4451 - accuracy: 0.7824
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4291 - accuracy: 0.8041
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4296 - accuracy: 0.8112
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4306 - accuracy: 0.8100
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4195 - accuracy: 0.8105
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4271 - accuracy: 0.8051
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4340 - accuracy: 0.8065
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4239 - accuracy: 0.8077
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4259 - accuracy: 0.8074
# 32/32 [==============================] - 1s 8ms/step - loss: 0.4778 - accuracy: 0.7786
# 32/32 [==============================] - 1s 8ms/step - loss: 0.5088 - accuracy: 0.7681
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4263 - accuracy: 0.8096
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4271 - accuracy: 0.8085
# Generation 11, Best Accuracy (Current): 0.8494
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4253 - accuracy: 0.8076
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4188 - accuracy: 0.8096
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4390 - accuracy: 0.8000
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4306 - accuracy: 0.8023
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4322 - accuracy: 0.8044
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4279 - accuracy: 0.8085
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4336 - accuracy: 0.8060
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4275 - accuracy: 0.8095
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4308 - accuracy: 0.8068
# 32/32 [==============================] - 1s 8ms/step - loss: 0.5085 - accuracy: 0.7710
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4256 - accuracy: 0.8079
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4512 - accuracy: 0.7970
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4279 - accuracy: 0.8046
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4238 - accuracy: 0.8072
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4319 - accuracy: 0.8074
# 32/32 [==============================] - 1s 6ms/step - loss: 0.5738 - accuracy: 0.7552
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4956 - accuracy: 0.7799
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4374 - accuracy: 0.8027
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4340 - accuracy: 0.8036
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4376 - accuracy: 0.8058
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4289 - accuracy: 0.8066
# Generation 12, Best Accuracy (Current): 0.8528
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4216 - accuracy: 0.8039
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4220 - accuracy: 0.8117
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4190 - accuracy: 0.8098
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4341 - accuracy: 0.8032
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4289 - accuracy: 0.8089
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4265 - accuracy: 0.8078
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4342 - accuracy: 0.8049
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4478 - accuracy: 0.7933
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4974 - accuracy: 0.7737
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4311 - accuracy: 0.8056
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4224 - accuracy: 0.8067
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4346 - accuracy: 0.8022
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4348 - accuracy: 0.7986
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4353 - accuracy: 0.8023
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4198 - accuracy: 0.8074
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4274 - accuracy: 0.8050
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4299 - accuracy: 0.8083
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4625 - accuracy: 0.7899
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4311 - accuracy: 0.8043
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4322 - accuracy: 0.8052
# Generation 13, Best Accuracy (Current): 0.8513
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4261 - accuracy: 0.8069
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4252 - accuracy: 0.8051
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4252 - accuracy: 0.8074
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4316 - accuracy: 0.8006
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4286 - accuracy: 0.8071
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4261 - accuracy: 0.8051
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4334 - accuracy: 0.8054
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4279 - accuracy: 0.8041
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4227 - accuracy: 0.8068
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4433 - accuracy: 0.7933
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4246 - accuracy: 0.8008
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4262 - accuracy: 0.8079
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4217 - accuracy: 0.8068
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4303 - accuracy: 0.8040
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4337 - accuracy: 0.8036
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4635 - accuracy: 0.7831
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4484 - accuracy: 0.7950
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4275 - accuracy: 0.8068
# 512/512 [==============================] - 2s 3ms/step - loss: 0.4145 - accuracy: 0.8162
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4340 - accuracy: 0.8045
# Generation 14, Best Accuracy (Current): 0.8509
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 17ms/step - loss: 0.4334 - accuracy: 0.8045
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4278 - accuracy: 0.8039
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4265 - accuracy: 0.8069
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4233 - accuracy: 0.8055
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4768 - accuracy: 0.7774
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4262 - accuracy: 0.8057
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4227 - accuracy: 0.8120
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4278 - accuracy: 0.8100
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4482 - accuracy: 0.7959
# 512/512 [==============================] - 2s 3ms/step - loss: 0.4116 - accuracy: 0.8189
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4236 - accuracy: 0.8082
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4138 - accuracy: 0.8145
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4271 - accuracy: 0.8046
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4271 - accuracy: 0.8085
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4265 - accuracy: 0.8010
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4250 - accuracy: 0.8118
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4322 - accuracy: 0.7996
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4182 - accuracy: 0.8117
# 512/512 [==============================] - 2s 3ms/step - loss: 0.4138 - accuracy: 0.8184
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4174 - accuracy: 0.8090
# Generation 15, Best Accuracy (Current): 0.8513
# Overall Best Accuracy: 0.8533
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4248 - accuracy: 0.8117
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4308 - accuracy: 0.8002
# 32/32 [==============================] - 1s 16ms/step - loss: 0.4188 - accuracy: 0.8100
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4281 - accuracy: 0.8099
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4333 - accuracy: 0.8030
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4225 - accuracy: 0.8080
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4302 - accuracy: 0.8054
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4242 - accuracy: 0.8029
# 32/32 [==============================] - 1s 7ms/step - loss: 0.4265 - accuracy: 0.8055
# 512/512 [==============================] - 2s 3ms/step - loss: 0.4100 - accuracy: 0.8209
# ...
# 128/128 [==============================] - 1s 5ms/step - loss: 0.3916 - accuracy: 0.8215
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4290 - accuracy: 0.8061
# 32/32 [==============================] - 1s 10ms/step - loss: 0.6600 - accuracy: 0.7362
# Generation 42, Best Accuracy (Current): 0.8509
# Overall Best Accuracy: 0.8562
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4214 - accuracy: 0.8067
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4274 - accuracy: 0.8035
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4340 - accuracy: 0.8046
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4238 - accuracy: 0.8045
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4166 - accuracy: 0.8091
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4316 - accuracy: 0.8054
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4292 - accuracy: 0.8084
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3922 - accuracy: 0.8223
# 512/512 [==============================] - 2s 3ms/step - loss: 0.4134 - accuracy: 0.8198
# 32/32 [==============================] - 1s 12ms/step - loss: 0.6625 - accuracy: 0.7421
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4330 - accuracy: 0.8065
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4274 - accuracy: 0.8089
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4298 - accuracy: 0.8095
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4219 - accuracy: 0.8118
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4215 - accuracy: 0.8071
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4255 - accuracy: 0.8079
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4342 - accuracy: 0.8065
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4249 - accuracy: 0.8084
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4303 - accuracy: 0.8027
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4314 - accuracy: 0.8078
# Generation 43, Best Accuracy (Current): 0.8523
# Overall Best Accuracy: 0.8562
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4289 - accuracy: 0.8041
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4421 - accuracy: 0.8036
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4276 - accuracy: 0.8034
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4296 - accuracy: 0.8060
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4287 - accuracy: 0.8105
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4355 - accuracy: 0.8056
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4255 - accuracy: 0.8079
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4317 - accuracy: 0.8057
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4207 - accuracy: 0.8112
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4318 - accuracy: 0.8023
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3966 - accuracy: 0.8238
# 32/32 [==============================] - 1s 10ms/step - loss: 0.6581 - accuracy: 0.7377
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4360 - accuracy: 0.8045
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4152 - accuracy: 0.7983
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4282 - accuracy: 0.8057
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4233 - accuracy: 0.8058
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4482 - accuracy: 0.7950
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4351 - accuracy: 0.7890
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4241 - accuracy: 0.8083
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4237 - accuracy: 0.8040
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4267 - accuracy: 0.8095
# Generation 44, Best Accuracy (Current): 0.8513
# Overall Best Accuracy: 0.8562
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4338 - accuracy: 0.8021
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4309 - accuracy: 0.8090
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4278 - accuracy: 0.7881
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4392 - accuracy: 0.8034
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4231 - accuracy: 0.8129
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4234 - accuracy: 0.8076
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4273 - accuracy: 0.8030
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3955 - accuracy: 0.8260
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4584 - accuracy: 0.7964
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4427 - accuracy: 0.7922
# 128/128 [==============================] - 1s 6ms/step - loss: 0.4003 - accuracy: 0.8221
# 32/32 [==============================] - 1s 16ms/step - loss: 0.8012 - accuracy: 0.6561
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4232 - accuracy: 0.8071
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4214 - accuracy: 0.8098
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4249 - accuracy: 0.8050
# 32/32 [==============================] - 1s 9ms/step - loss: 0.4299 - accuracy: 0.8051
# 32/32 [==============================] - 1s 19ms/step - loss: 0.5157 - accuracy: 0.7520
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4180 - accuracy: 0.8100
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4198 - accuracy: 0.8096
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4833 - accuracy: 0.7605
# Generation 45, Best Accuracy (Current): 0.8538
# Overall Best Accuracy: 0.8562
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4383 - accuracy: 0.8035
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4294 - accuracy: 0.8054
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4312 - accuracy: 0.8094
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4232 - accuracy: 0.8087
# 32/32 [==============================] - 1s 20ms/step - loss: 0.5256 - accuracy: 0.7508
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4150 - accuracy: 0.8151
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4306 - accuracy: 0.8041
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3967 - accuracy: 0.8200
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4797 - accuracy: 0.7725
# 32/32 [==============================] - 1s 15ms/step - loss: 0.8034 - accuracy: 0.6615
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4276 - accuracy: 0.8087
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4248 - accuracy: 0.8095
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4225 - accuracy: 0.8073
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3931 - accuracy: 0.8236
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4249 - accuracy: 0.8095
# 256/256 [==============================] - 3s 5ms/step - loss: 0.4751 - accuracy: 0.7984
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4324 - accuracy: 0.7995
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4730 - accuracy: 0.7776
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3995 - accuracy: 0.8212
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4261 - accuracy: 0.8066
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4303 - accuracy: 0.8058
# Generation 46, Best Accuracy (Current): 0.8479
# Overall Best Accuracy: 0.8562
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4222 - accuracy: 0.8099
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4294 - accuracy: 0.8066
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3975 - accuracy: 0.8225
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4197 - accuracy: 0.8080
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4277 - accuracy: 0.8052
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4217 - accuracy: 0.8054
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4260 - accuracy: 0.8102
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3916 - accuracy: 0.8221
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4723 - accuracy: 0.7759
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4197 - accuracy: 0.8112
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4873 - accuracy: 0.7714
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4296 - accuracy: 0.8052
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4158 - accuracy: 0.8105
# 128/128 [==============================] - 2s 8ms/step - loss: 0.4425 - accuracy: 0.8083
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4468 - accuracy: 0.7947
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3997 - accuracy: 0.8219
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4282 - accuracy: 0.8072
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4348 - accuracy: 0.8062
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3909 - accuracy: 0.8231
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4530 - accuracy: 0.8082
# Generation 47, Best Accuracy (Current): 0.8523
# Overall Best Accuracy: 0.8562
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4241 - accuracy: 0.8113
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3910 - accuracy: 0.8241
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4165 - accuracy: 0.8110
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4297 - accuracy: 0.8067
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3952 - accuracy: 0.8236
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4872 - accuracy: 0.7604
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4519 - accuracy: 0.7940
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4485 - accuracy: 0.7813
# 128/128 [==============================] - 1s 7ms/step - loss: 0.4413 - accuracy: 0.8088
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4213 - accuracy: 0.8104
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4296 - accuracy: 0.8093
# 128/128 [==============================] - 1s 7ms/step - loss: 0.3985 - accuracy: 0.8232
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4210 - accuracy: 0.8087
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4575 - accuracy: 0.7902
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4182 - accuracy: 0.8143
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4251 - accuracy: 0.8113
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3958 - accuracy: 0.8226
# 32/32 [==============================] - 1s 30ms/step - loss: 0.4245 - accuracy: 0.8104
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3927 - accuracy: 0.8261
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4274 - accuracy: 0.8080
# Generation 48, Best Accuracy (Current): 0.8479
# Overall Best Accuracy: 0.8562
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3942 - accuracy: 0.8242
# 32/32 [==============================] - 1s 28ms/step - loss: 0.4293 - accuracy: 0.8028
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4232 - accuracy: 0.8030
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4254 - accuracy: 0.8088
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4222 - accuracy: 0.8058
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4289 - accuracy: 0.8101
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3903 - accuracy: 0.8272
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4256 - accuracy: 0.8098
# 128/128 [==============================] - 1s 6ms/step - loss: 0.3971 - accuracy: 0.8232
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4414 - accuracy: 0.7915
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4252 - accuracy: 0.8094
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4292 - accuracy: 0.8041
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4250 - accuracy: 0.8098
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4238 - accuracy: 0.8055
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4203 - accuracy: 0.8110
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4247 - accuracy: 0.8090
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4263 - accuracy: 0.8028
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4245 - accuracy: 0.8085
# 32/32 [==============================] - 1s 12ms/step - loss: 0.6084 - accuracy: 0.7495
# 32/32 [==============================] - 1s 15ms/step - loss: 0.6615 - accuracy: 0.7344
# Generation 49, Best Accuracy (Current): 0.8518
# Overall Best Accuracy: 0.8562
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4240 - accuracy: 0.8109
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4318 - accuracy: 0.8055
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4326 - accuracy: 0.8049
# 32/32 [==============================] - 1s 10ms/step - loss: 0.4284 - accuracy: 0.8078
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4345 - accuracy: 0.8035
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4315 - accuracy: 0.8044
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4393 - accuracy: 0.8028
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4267 - accuracy: 0.8089
# 32/32 [==============================] - 1s 12ms/step - loss: 0.6199 - accuracy: 0.7492
# 32/32 [==============================] - 1s 12ms/step - loss: 0.6588 - accuracy: 0.7364
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4091 - accuracy: 0.8127
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4229 - accuracy: 0.8100
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4275 - accuracy: 0.8094
# 32/32 [==============================] - 1s 11ms/step - loss: 0.4291 - accuracy: 0.8052
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4265 - accuracy: 0.8090
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4188 - accuracy: 0.8123
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4283 - accuracy: 0.8038
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4165 - accuracy: 0.8113
# 32/32 [==============================] - 1s 29ms/step - loss: 0.4154 - accuracy: 0.8079
# 32/32 [==============================] - 1s 13ms/step - loss: 0.4249 - accuracy: 0.8087
# 32/32 [==============================] - 1s 12ms/step - loss: 0.4280 - accuracy: 0.8033
# Generation 50, Best Accuracy (Current): 0.8528
# Overall Best Accuracy: 0.8562
#
# Final Best Chromosome and Accuracy:
# Best Chromosome: {'learning_rate': 0.017369761613612176, 'batch_size': 256, 'num_layers': 1, 'filters_per_layer': 128, 'kernel_size': (5, 5), 'activation': 'tanh', 'pooling_type': 'AveragePooling', 'optimizer': 'RMSprop', 'neurons_per_layer': 32}
# Best Accuracy: 0.8562
#
# Results for 10 Population and 50 Generations:
# Best Chromosome: {'learning_rate': 0.017369761613612176, 'batch_size': 256, 'num_layers': 1, 'filters_per_layer': 128, 'kernel_size': (5, 5), 'activation': 'tanh', 'pooling_type': 'AveragePooling', 'optimizer': 'RMSprop', 'neurons_per_layer': 32}
# Best Accuracy: 0.8562
#
# Comparison:
# Accuracy Improvement: 0.0059
